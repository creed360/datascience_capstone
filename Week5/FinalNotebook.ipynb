# %% [markdown]
# # THE BATTLE OF NEIGHBORHOODS

# %% [markdown]
# # Introduction:

# %% [markdown]
# New York City's demographics show that it is a large and ethnically diverse metropolis. With it's diverse culture , comes diverse food items. There are many resturants in New york City, each beloning to different categories like Chinese , Indian , French etc.
#
# So as part of this project , we will list and visualize all major parts of New York City that has great indian resturants.

# %% [markdown]
# # Data:

# %% [markdown]
# For this project we need the following data:
# 1. New York City data that contains list Boroughs, Neighborhoods along with their latitude and longitude.
# 2. Indian resturants in each neighborhood of new york city.
# 3. GeoSpace data

# %% [markdown]
# ## Questions that will be answers at the end of this project :

# %% [markdown]
# ### 1. What are best location in New York City for Indian Cuisine?
# ### 2. Which areas have potential Indian Restaurant Market?
# ### 3. Which all areas lack Indian Restaurants?
# ### 4. Which is the best place to stay if you prefer Indian Cuisine?

# %% [markdown]
# # Methodology:

# %% [markdown]
# 1. We begin by collecting the New York city data from "https://cocl.us/new_york_dataset".
# 2. We will find all venues for each neighborhood using FourSquare API.
# 3. We will then filter out all Indian Restuarant venues.
# 4. Next using FourSquare API, we will find the Ratings, Tips, and Like count for all the Indian Resturants.
# 5. Next we will sort the data keeping Ratings as the constraint.
# 6. Finally, we will visualize the Ranking of neighborhoods using python's Folium library.

# %% [markdown]
# Lets Start by importing the required Libraries.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
#!conda install -c conda-forge geocoder -y
import geocoder
import os
#!pip install folium
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now we define a function to get the geocodes i.e latitude and longitude of a given location using geopy.

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %% [markdown]
# We define a function to intract with FourSquare API and get top 100 venues within a radius of 1000 metres for a given latitude and longitude. Below function will return us the venue id , venue name and category.

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = '2NEJDJUXJX11KNIA2SVQ2G2HNSIW3VRGJR3SVNTUNKMHNOII' # your Foursquare ID
    CLIENT_SECRET = 'EI153WDVGMN3DYF3OHNXEDYIIPUXHPVUMU4EPSRMAKKTYSCU' # your Foursquare Secret
    VERSION = '20200401' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# Now we will define a function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking.

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = '2NEJDJUXJX11KNIA2SVQ2G2HNSIW3VRGJR3SVNTUNKMHNOII' # your Foursquare ID
    CLIENT_SECRET = 'EI153WDVGMN3DYF3OHNXEDYIIPUXHPVUMU4EPSRMAKKTYSCU' # your Foursquare Secret
    VERSION = '20200401' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# Now we define a funtion to get the new york city data such as Boroughs, Neighborhoods along with their latitude and longitude.

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %% [markdown]
# We will call the above funtion to get the new york city data.

# %%
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %% [markdown]
# ### The above result shows that there are 306 different Neighborhoods in New York.

# %% [markdown]
# Now let create a BAR PLOT to show different Neighborhoods in New York.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=15)
#giving a bar plot
new_york_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### From the above Bar Plot, we can see that Queens has highest number of neighborhoods.

# %% [markdown]
# Next we will collect Indian resturants for each Neighborhood.

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
indian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
# ( 305 / 306 ) Indian Resturants in Queensbridge, Queens:2
# ( 306 / 306 ) Indian Resturants in Fox Hills, Staten Island:0

# %% [markdown]
# Now that we have got all the indian resturants in new york city , we will analyze it.

# %%
indian_rest_ny.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx        Woodlawn  4c0448d9310fc9b6bf1dc761
# 1   Bronx     Parkchester  4c194631838020a13e78e561
# 2   Bronx  Spuyten Duyvil  4c04544df423a593ac83d116
# 3   Bronx       Concourse  551b7f75498e86c00a0ed2e1
# 4   Bronx       Unionport  4c194631838020a13e78e561
#
#                           Name
# 0                   Curry Spot
# 1  Melanies Roti Bar And Grill
# 2         Cumin Indian Cuisine
# 3                  Hungry Bird
# 4  Melanies Roti Bar And Grill

# %%
indian_rest_ny.shape
# Out:
# (140, 4)

# %% [markdown]
# ### From the above result, we see that there are 151 Indian Resturants across New York City.

# %% [markdown]
# Now let create a BAR PLOT to show Number of Indian Resturants for each Borough in New York City.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Resturants', fontsize=15)
#giving a bar plot
indian_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### From the above Bar Plot, we can see that Queens has highest number of Indian resturants.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Indian Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Indian Resturants', fontsize=15)
#giving a bar plot
indian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
indian_rest_ny[indian_rest_ny['Neighborhood']=='Floral Park']
# Out:
#     Borough Neighborhood                        ID  \
# 100  Queens  Floral Park  527ffc0811d2d329d5e49abd
# 101  Queens  Floral Park  4e4e3e22bd4101d0d7a5c2d1
# 102  Queens  Floral Park  4b647b56f964a520c4b62ae3
# 103  Queens  Floral Park  4b787c49f964a5209cd12ee3
# 104  Queens  Floral Park  4c0c01e0bbc676b00d6b4cd5
# 105  Queens  Floral Park  4c76ff35a5676dcb72671721
# 106  Queens  Floral Park  4df0f39dd4c04d0392c853ea
# 107  Queens  Floral Park  55d68c1b498ecf05fa196fe1
# 108  Queens  Floral Park  4e6bfe1c7d8b2c711b17bbe5
#
#                             Name
# 100                Jackson Diner
# 101               Kerala Kitchen
# 102     Usha Foods & Usha Sweets
# 103    Santoor Indian Restaurant
# 104                Mumbai Xpress
# 105              Flavor Of India
# 106                Sagar Chinese
# 107  Namaste Restaurant and Cafe
# 108      Surya sweets and snacks

# %% [markdown]
# ### We can see that, Floral Park in Queens has the highest number of Indian Resturants with a total count of 11.

# %% [markdown]
# Now we will get the ranking of each resturant for further analysis.

# %%
indian_rest_ny.values.tolist()
# Out:
# [['Bronx', 'Woodlawn', '4c0448d9310fc9b6bf1dc761', 'Curry Spot'],
#  ['Bronx',
#   'Parkchester',
#   '4c194631838020a13e78e561',
#   'Melanies Roti Bar And Grill'],
#  ['Bronx',
#   'Spuyten Duyvil',
#   '4c04544df423a593ac83d116',
#   'Cumin Indian Cuisine'],
#  ['Bronx', 'Concourse', '551b7f75498e86c00a0ed2e1', 'Hungry Bird'],
#  ['Bronx',
#   'Unionport',
#   '4c194631838020a13e78e561',
#   'Melanies Roti Bar And Grill'],
#  ['Brooklyn', 'Bay Ridge', '4b5a4dc8f964a520a2bb28e3', 'Taj Mahal'],
#  ['Brooklyn', 'Bay Ridge', '545835a1498e820edc6f636f', 'Bombay Grill'],
#  ['Brooklyn', 'Brighton Beach', '4af0d31bf964a5207ddf21e3', 'Pak Nasheman'],
#  ['Brooklyn', 'Flatbush', '52213c4211d295d4c57a607c', 'Ashoka Grill'],
#  ['Brooklyn', 'Flatbush', '564d283d498e6e851df79d87', 'Great Indian Curry'],
#  ['Brooklyn', 'East Flatbush', '512a9ea9e4b004fb8eeb84e5', 'Silver Krust'],
#  ['Brooklyn', 'Kensington', '4db0f4371e729fcc56497f20', 'Mashallah'],
#  ['Brooklyn',
#   'Kensington',
#   '4b718914f964a520c04b2de3',
#   'Madina Restaurant and Sweets'],
#  ['Brooklyn', 'Prospect Heights', '592e1dae345cbe0fc77cf6c9', 'Diwan Grill'],
#  ['Brooklyn',
#   'Gowanus',
#   '52f18573498ec2c34e830ffd',
#   "Kanan's Indian Restaurant"],
#  ['Brooklyn', 'Fort Greene', '57596dad498e732300496b23', 'Dosa Royale'],
#  ['Brooklyn', 'Clinton Hill', '57596dad498e732300496b23', 'Dosa Royale'],
#  ['Brooklyn', 'Downtown', '543870ec498ec64de510608d', 'Masala Grill'],
#  ['Brooklyn',
#   'Prospect Lefferts Gardens',
#   '4bb93b70cf2fc9b6fe64a002',
#   'Gandhi Fine Indian Cuisine'],
#  ['Brooklyn', 'Ocean Hill', '5539753f498edbace4746b67', 'Tandoori Masala'],
#  ['Brooklyn', 'Ocean Hill', '4f6cae2ee4b0d4a5afcef5c0', 'Delhi Heights'],
#  ['Brooklyn',
#   'Prospect Park South',
#   '519ff6c8498e1300ddcbd45c',
#   'Anarkali Indian Cuisine'],
#  ['Brooklyn', 'Prospect Park South', '4db0f4371e729fcc56497f20', 'Mashallah'],
#  ['Brooklyn', 'Fort Hamilton', '545835a1498e820edc6f636f', 'Bombay Grill'],
#  ['Manhattan',
#   'Washington Heights',
#   '4ae7876ef964a5201eac21e3',
#   'Kismat Indian Restaurant'],
#  ['Manhattan',
#   'Hamilton Heights',
#   '54c2bd96498eaf5142e3fe92',
#   'Clove Indian Restaurant & Bar'],
#  ['Manhattan',
#   'Hamilton Heights',
#   '5914ff32b23dfa207eca38de',
#   'Mumbai Masala'],
#  ['Manhattan',
#   'Manhattanville',
#   '529d382a11d2dd5ef107e641',
#   'Chapati House - NYC'],
#  ['Manhattan',
#   'Manhattanville',
#   '54c2bd96498eaf5142e3fe92',
#   'Clove Indian Restaurant & Bar'],
#  ['Manhattan', 'Central Harlem', '56d87f3d498ee215abee5724', 'Delhi Masala'],
#  ['Manhattan',
#   'Central Harlem',
#   '54c2bd96498eaf5142e3fe92',
#   'Clove Indian Restaurant & Bar'],
#  ['Manhattan', 'East Harlem', '519fe6f5498e30595d370c44', 'Bawarchi'],
#  ['Manhattan', 'Yorkville', '5272ca4511d22488f6895caf', 'Drunken Munkey'],
#  ['Manhattan',
#   'Yorkville',
#   '56ed855a498ef3bb022352c3',
#   'Mughlai Indian Cuisine'],
#  ['Manhattan',
#   'Roosevelt Island',
#   '4fe4fb50c2eee335e4fea69d',
#   'Moti Mahal Delux'],
#  ['Manhattan', 'Upper West Side', '42489a80f964a5208b201fe3', 'Swagat'],
#  ['Manhattan', 'Midtown', '5953e40462420b044e8989f4', 'indikitch'],
#  ['Manhattan', 'Midtown', '4acf6ed7f964a520a0d320e3', 'Cafe Spice'],
#  ['Manhattan',
#   'Murray Hill',
#   '59fcd48c464d6567ed2f5e37',
#   'The Kati Roll Company'],
#  ['Manhattan', 'Chelsea', '4b4aab62f964a520978c26e3', 'Dil-e Punjab Deli'],
#  ['Manhattan', 'West Village', '591794df2be42556988e4a8e', 'Rahi'],
#  ['Manhattan',
#   'Manhattan Valley',
#   '424de080f964a520ae201fe3',
#   'Manhattan Valley'],
#  ['Manhattan', 'Manhattan Valley', '538ba1f2498e279098e4210a', 'Awadh'],
#  ['Manhattan', 'Manhattan Valley', '49c5ad0af964a5201b571fe3', 'Roti Roll'],
#  ['Manhattan', 'Morningside Heights', '49c5ad0af964a5201b571fe3', 'Roti Roll'],
#  ['Manhattan', 'Gramercy', '4a70a75bf964a52016d81fe3', 'Bhatti Indian Grill'],
#  ['Manhattan', 'Gramercy', '57f7cbbe498edf8f07c7ba83', 'Sahib'],
#  ['Manhattan', 'Gramercy', '4a12eb1ff964a52099771fe3', 'Dhaba'],
#  ['Manhattan', 'Gramercy', '4fcf82f54fc6ada5874da997', 'Chote Nawab'],
#  ['Manhattan', 'Gramercy', '43d537d0f964a520402e1fe3', 'Vatan'],
#  ['Queens', 'Astoria', '4aa56c81f964a5204e4820e3', 'Seva Indian Cuisine'],
#  ['Queens', 'Woodside', '4afdcf29f964a520162b22e3', 'Rajbhog Sweets'],
#  ['Queens', 'Woodside', '4c7060e734443704ca0e245f', 'Kababish'],
#  ['Queens',
#   'Woodside',
#   '4b998d3ff964a520fc8235e3',
#   'Maharaja Sweets & Snacks'],
#  ['Queens', 'Woodside', '4b189424f964a52043d423e3', 'Dera'],
#  ['Queens', 'Woodside', '5da4fbf091a08400078be19d', 'Angel Indian Restaurant'],
#  ['Queens', 'Woodside', '49ebb18ff964a52016671fe3', 'Delhi Heights'],
#  ['Queens',
#   'Woodside',
#   '4e334b7bb0fb17f64f81a8b2',
#   'Premium Sweets & Restaurant'],
#  ['Queens', 'Woodside', '3fd66200f964a52009f11ee3', 'Jackson Diner'],
#  ['Queens', 'Jackson Heights', '527d9cbc498edf0db10bde6b', 'Samudra'],
#  ['Queens', 'Jackson Heights', '4afdcf29f964a520162b22e3', 'Rajbhog Sweets'],
#  ['Queens',
#   'Jackson Heights',
#   '4b998d3ff964a520fc8235e3',
#   'Maharaja Sweets & Snacks'],
#  ['Queens',
#   'Jackson Heights',
#   '5da4fbf091a08400078be19d',
#   'Angel Indian Restaurant'],
#  ['Queens', 'Jackson Heights', '49ebb18ff964a52016671fe3', 'Delhi Heights'],
#  ['Queens', 'Elmhurst', '527d9cbc498edf0db10bde6b', 'Samudra'],
#  ['Queens', 'Elmhurst', '5da4fbf091a08400078be19d', 'Angel Indian Restaurant'],
#  ['Queens', 'Elmhurst', '49ebb18ff964a52016671fe3', 'Delhi Heights'],
#  ['Queens', 'Elmhurst', '4a4e780ff964a52083ae1fe3', 'Tangra Masala'],
#  ['Queens', 'Kew Gardens', '5782c9ce498edde587f5aa14', 'Tikka Indian Grill'],
#  ['Queens',
#   'Kew Gardens',
#   '4bbe78bfba9776b070cefdc8',
#   'Mehak Mughlai Cuisine'],
#  ['Queens', 'Richmond Hill', '4b522029f964a520f26927e3', 'Sohna Punjab'],
#  ['Queens', 'Richmond Hill', '5782c9ce498edde587f5aa14', 'Tikka Indian Grill'],
#  ['Queens', 'Richmond Hill', '4f1b77d7e4b044fd359e6d21', 'India Cafe'],
#  ['Queens', 'Richmond Hill', '4bb2bc48a32876b02e0b01fe', 'Tandoori Hut'],
#  ['Queens',
#   'Richmond Hill',
#   '4adbaef0f964a520ff2921e3',
#   'Punjabi Kabab House'],
#  ['Queens', 'Richmond Hill', '4babc24ef964a5200ac73ae3', 'Royal India Palace'],
#  ['Queens', 'Richmond Hill', '57d9e9a1498e545076560fef', 'Punjabi Diner'],
#  ['Queens',
#   'Long Island City',
#   '50a287a7e4b0033f830f06db',
#   "Raj's Indian Kitchen"],
#  ['Queens', 'Long Island City', '5b931ea69d7468002c3b1382', 'Adda'],
#  ['Queens',
#   'Long Island City',
#   '4b1b341bf964a5208af923e3',
#   'Five Star Banquet'],
#  ['Queens', 'Sunnyside', '5b931ea69d7468002c3b1382', 'Adda'],
#  ['Queens',
#   'Ridgewood',
#   '50e1c9708aca7ff2b3e50353',
#   'Nepalese Indian Restaurant'],
#  ['Queens', 'Rego Park', '5625af69498ebbc62b61a382', 'Aaheli Restaurant'],
#  ['Queens', 'South Ozone Park', '4ee8dddb5c5c99a2dc780825', 'New Kabob Diner'],
#  ['Queens',
#   'Bayside',
#   '4f1f4996e4b01ff351a7a50c',
#   'Ayna Agra Indian Restaurant'],
#  ['Queens', 'Bayside', '539a4ff0498e79c6745baba9', 'Masala Box'],
#  ['Queens', 'Bayside', '539e27b0498e2eba582085ee', 'masalabox'],
#  ['Queens',
#   'Glen Oaks',
#   '4b787c49f964a5209cd12ee3',
#   'Santoor Indian Restaurant'],
#  ['Queens', 'Glen Oaks', '4b9030abf964a520397b33e3', 'Taste of Cochin'],
#  ['Queens', 'Glen Oaks', '4c0e256ab1b676b06589e186', 'Sohna Punjab'],
#  ['Queens', 'Glen Oaks', '4df0f39dd4c04d0392c853ea', 'Sagar Chinese'],
#  ['Queens',
#   'Kew Gardens Hills',
#   '4b96926df964a520abd534e3',
#   'Khyber Indian Restaurant'],
#  ['Queens',
#   'Briarwood',
#   '4be334312fc7d13a7a81083a',
#   'Taj Mahal Restaurant & Party Hall'],
#  ['Queens', 'Briarwood', '4bad49a0f964a52041423be3', 'Annam Brahma'],
#  ['Queens', 'Briarwood', '4cc08b0900d83704ed474b5c', "Sybil's Bakery"],
#  ['Queens', 'Jamaica Center', '4bad49a0f964a52041423be3', 'Annam Brahma'],
#  ['Queens', 'Jamaica Center', '4c434b2bd691c9b6ef8f8f0a', 'Sagar Restaurant'],
#  ['Queens', 'Jamaica Center', '4cc08b0900d83704ed474b5c', "Sybil's Bakery"],
#  ['Queens',
#   'Jamaica Center',
#   '4c69c4b58e7c0f47d48de00f',
#   'Ghoroa Sweets & Restaurant'],
#  ['Queens', 'Steinway', '562035d9498e2abb4137c2c7', 'Yaar Indian Restaurant'],
#  ['Queens', 'Floral Park', '527ffc0811d2d329d5e49abd', 'Jackson Diner'],
#  ['Queens', 'Floral Park', '4e4e3e22bd4101d0d7a5c2d1', 'Kerala Kitchen'],
#  ['Queens',
#   'Floral Park',
#   '4b647b56f964a520c4b62ae3',
#   'Usha Foods & Usha Sweets'],
#  ['Queens',
#   'Floral Park',
#   '4b787c49f964a5209cd12ee3',
#   'Santoor Indian Restaurant'],
#  ['Queens', 'Floral Park', '4c0c01e0bbc676b00d6b4cd5', 'Mumbai Xpress'],
#  ['Queens', 'Floral Park', '4c76ff35a5676dcb72671721', 'Flavor Of India'],
#  ['Queens', 'Floral Park', '4df0f39dd4c04d0392c853ea', 'Sagar Chinese'],
#  ['Queens',
#   'Floral Park',
#   '55d68c1b498ecf05fa196fe1',
#   'Namaste Restaurant and Cafe'],
#  ['Queens',
#   'Floral Park',
#   '4e6bfe1c7d8b2c711b17bbe5',
#   'Surya sweets and snacks'],
#  ['Queens',
#   'Holliswood',
#   '4f580c1be4b0bdfd0e7e8102',
#   'Rajdhani Indian Restaurant'],
#  ['Queens', 'Jamaica Estates', '4c434b2bd691c9b6ef8f8f0a', 'Sagar Restaurant'],
#  ['Queens',
#   'Jamaica Estates',
#   '4b8d5734f964a520b1f532e3',
#   'BBQ Village Palace'],
#  ['Queens',
#   'Jamaica Estates',
#   '4c66f1ac8e9120a1b266d964',
#   'Sunshine Grill and Restaurant'],
#  ['Queens', 'Ravenswood', '5623f6f9498e5a44a08bfae8', 'Boishakhi Restaurant'],
#  ['Queens', 'Bellaire', '4dc0aaedae606fe8b71c226b', 'Saffron Cuisine/ Bar'],
#  ['Queens', 'Forest Hills Gardens', '4f188adfe4b0cae4b525a694', 'Haveli'],
#  ['Staten Island', 'New Brighton', '4b9be038f964a520393036e3', 'Dosa Garden'],
#  ['Staten Island',
#   'New Dorp',
#   '4be74a502468c928505a0243',
#   'Taste Of India II'],
#  ['Staten Island', 'Tompkinsville', '4b9be038f964a520393036e3', 'Dosa Garden'],
#  ['Brooklyn', 'Ditmas Park', '4db0f4371e729fcc56497f20', 'Mashallah'],
#  ['Brooklyn',
#   'Ditmas Park',
#   '519ff6c8498e1300ddcbd45c',
#   'Anarkali Indian Cuisine'],
#  ['Brooklyn', 'Ditmas Park', '564d283d498e6e851df79d87', 'Great Indian Curry'],
#  ['Staten Island',
#   'Grant City',
#   '4be74a502468c928505a0243',
#   'Taste Of India II'],
#  ['Manhattan', 'Carnegie Hill', '5272ca4511d22488f6895caf', 'Drunken Munkey'],
#  ['Queens', 'Jamaica Hills', '4bad49a0f964a52041423be3', 'Annam Brahma'],
#  ['Queens', 'Jamaica Hills', '4c434b2bd691c9b6ef8f8f0a', 'Sagar Restaurant'],
#  ['Queens', 'Jamaica Hills', '4cc08b0900d83704ed474b5c', "Sybil's Bakery"],
#  ['Queens', 'Jamaica Hills', '4cb4a712db32f04dcb5adf4d', 'Moon Tikka'],
#  ['Queens', 'Astoria Heights', '4c2e8df2213c2d7f94742f5d', 'Tikka Grill'],
#  ['Bronx', 'Concourse Village', '551b7f75498e86c00a0ed2e1', 'Hungry Bird'],
#  ['Manhattan', 'Sutton Place', '4fe4fb50c2eee335e4fea69d', 'Moti Mahal Delux'],
#  ['Manhattan',
#   'Turtle Bay',
#   '59fcd48c464d6567ed2f5e37',
#   'The Kati Roll Company'],
#  ['Manhattan', 'Turtle Bay', '4a5b660df964a52015bb1fe3', 'Amma'],
#  ['Manhattan',
#   'Tudor City',
#   '59fcd48c464d6567ed2f5e37',
#   'The Kati Roll Company'],
#  ['Queens', 'Sunnyside Gardens', '4c48da9f3013a59356c5f0e1', 'Saffron Garden'],
#  ['Queens', 'Blissville', '5b931ea69d7468002c3b1382', 'Adda'],
#  ['Brooklyn',
#   'Broadway Junction',
#   '5539753f498edbace4746b67',
#   'Tandoori Masala'],
#  ['Brooklyn', 'Erasmus', '564d283d498e6e851df79d87', 'Great Indian Curry'],
#  ['Queens',
#   'Queensbridge',
#   '50a287a7e4b0033f830f06db',
#   "Raj's Indian Kitchen"],
#  ['Queens', 'Queensbridge', '4b1b341bf964a5208af923e3', 'Five Star Banquet']]

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in indian_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(indian_rest_ny),')','processed')
    indian_rest_stats_ny = indian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
# {'meta': {'code': 200, 'requestId': '5eb3c1d76d8c56001ba99e9c'}, 'response': {'venue': {'id': '4c0448d9310fc9b6bf1dc761', 'name': 'Curry Spot', 'contact': {'phone': '7187085900', 'formattedPhone': '(718) 708-5900'}, 'location': {'address': '4268 Katonah Ave', 'crossStreet': 'E 235 Street', 'lat': 40.897624941880906, 'lng': -73.86714729157393, 'labeledLatLngs': [{'label': 'display', 'lat': 40.897624941880906, 'lng': -73.86714729157393}, {'label': 'entrance', 'lat': 40.897709, 'lng': -73.86707}], 'postalCode': '10470', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4268 Katonah Ave (E 235 Street)', 'Bronx, NY 10470', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/curry-spot/4c0448d9310fc9b6bf1dc761', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 10}, 'url': 'https://thecurryspotbronx.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'id': '10110535', 'firstName': 'Dario', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZGUOOGAHGRDBRYJF.jpg'}}, {'id': '102792', 'firstName': 'Mike', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/102792_1258663222573.jpg'}}, {'id': '19285500', 'firstName': 'Jackie', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/19285500_a5dQzVHp_jRTQ-h--mlNfoVI3XoR4Oas5ZLOQaQ9-nIDuViZLJEICPZI7jtAQtdko-C0Ib6wU.jpg'}}]}], 'summary': '5 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.8, 'ratingColor': 'C5DE35', 'ratingSignals': 12, 'delivery': {'id': '73072', 'url': 'https://www.seamless.com/menu/the-curry-spot-4268-katonah-ave-bronx/73072?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=73072', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/curry-spot/4c0448d9310fc9b6bf1dc761/menu', 'mobileUrl': 'https://foursquare.com/v/4c0448d9310fc9b6bf1dc761/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 26, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 26, 'items': [{'id': '513e67bae4b023017d40a8aa', 'createdAt': 1363044282, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/19358265_vapqFxzfhBIx5HFvQhN8OXKkP3B7squgDy2ODsl28IA.jpg', 'width': 540, 'height': 720, 'user': {'id': '19358265', 'firstName': 'Vish', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/UHUOWEXX2MBZDULD.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1275349209, 'tips': {'count': 10, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 10, 'items': [{'id': '5243a3bb498e70058db6e94f', 'createdAt': 1380164539, 'text': 'BYOB, fantastic food and service!! I will definitely go again. The naan, mango chutney, chicken bhuna, and vegetable korma were great', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5243a3bb498e70058db6e94f', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '41626362', 'firstName': 'James', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4 ...
#                          ID        Name  Likes  Rating  Tips
# 0  4c0448d9310fc9b6bf1dc761  Curry Spot      5     7.8    10
# ( 1 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c27eb57e88001b527fc4'}, 'response': {'venue': {'id': '4c194631838020a13e78e561', 'name': 'Melanies Roti Bar And Grill', 'contact': {'phone': '7184091088', 'formattedPhone': '(718) 409-1088'}, 'location': {'address': '1248 Castle Hill Ave', 'crossStreet': 'Newbold Ave', 'lat': 40.833293, 'lng': -73.85104, 'labeledLatLngs': [{'label': 'display', 'lat': 40.833293, 'lng': -73.85104}, {'label': 'entrance', 'lat': 40.833276, 'lng': -73.851166}], 'postalCode': '10462', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1248 Castle Hill Ave (Newbold Ave)', 'Bronx, NY 10462', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/melanies-roti-bar-and-grill/4c194631838020a13e78e561', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '85063300', 'firstName': 'Herbie', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/85063300-Z0EBLTSF2HA332NN.jpg'}}, {'id': '27574660', 'firstName': 'Ronny', 'lastName': 'O', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/27574660_qYfiOHLf_oBSOCTf25k5xBfNxi46hyVIAru4KIR76_dMR8yoIkJXSlJjtCFwcte3v5ACuyKWL.jpg'}}, {'id': '126099277', 'firstName': 'Michelle', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/126099277-1RYNZ5EKS1WDY5HW.jpg'}}]}], 'summary': '3 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.0, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'delivery': {'id': '72260', 'url': 'https://www.seamless.com/menu/melanies-roti--grill-restaurant-1248-castle-hill-ave-bronx/72260?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72260', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/melanies-roti-bar-and-grill/4c194631838020a13e78e561/menu', 'mobileUrl': 'https://foursquare.com/v/4c194631838020a13e78e561/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1, 'items': [{'id': '4f9ee2d1e4b0e868c4812372', 'createdAt': 1335812817, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/erNpDYL_cghKUK2JjgQFs2bl0MVCEyA9Tzi-UX5cMRo.jpg', 'width': 540, 'height': 720, 'user': {'id': '19512833', 'firstName': 'Tanisha', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KH1ES1XV1UWC1O4S.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1276724785, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '5424b5d1498e2280e91127f3', 'createdAt': 1411691985, 'text': 'Cashier messed up the order I ordered pork lowmein and chicken fried rice. Instead received pork fried rice and chicken fried rice', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5424b5d1498e2280e91127f3', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '27574660', 'firstName': 'Ronny', 'lastName': 'O', 'photo': {'prefix' ...
#                          ID                         Name  Likes  Rating  Tips
# 0  4c194631838020a13e78e561  Melanies Roti Bar And Grill      3     6.0     2
# ( 2 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c1e07828ae001bb5b8c6'}, 'response': {'venue': {'id': '4c04544df423a593ac83d116', 'name': 'Cumin Indian Cuisine', 'contact': {}, 'location': {'address': '3549 Johnson Ave', 'lat': 40.886458613786466, 'lng': -73.90981597247142, 'labeledLatLngs': [{'label': 'display', 'lat': 40.886458613786466, 'lng': -73.90981597247142}, {'label': 'entrance', 'lat': 40.886478, 'lng': -73.90987}], 'postalCode': '10463', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['3549 Johnson Ave', 'Bronx, NY 10463', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/cumin-indian-cuisine/4c04544df423a593ac83d116', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 9}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.0, 'ratingColor': 'FFC800', 'ratingSignals': 23, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/cumin-indian-cuisine/4c04544df423a593ac83d116/menu', 'mobileUrl': 'https://foursquare.com/v/4c04544df423a593ac83d116/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 4, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 4, 'items': [{'id': '51fee007498e911dcd819881', 'createdAt': 1375657991, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/44577417_Vq6RogwT-tJmb9rO2rOnka3670fOxZWiSJl-vZ8qLOg.jpg', 'width': 720, 'height': 960, 'user': {'id': '44577417', 'firstName': 'Eva', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/44577417-0NTO4EDAE3FB5SHM.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1275352141, 'tips': {'count': 9, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 9, 'items': [{'id': '4ca8fc27b0b8236a471fb9e6', 'createdAt': 1286143015, 'text': 'Ask the waiter Habib for suggestions on what to order.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4ca8fc27b0b8236a471fb9e6', 'lang': 'en', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '44577417', 'firstName': 'Eva', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/44577417-0NTO4EDAE3FB5SHM.jpg'}}]}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '2318671', 'firstName': 'Tara', 'lastName': 'N', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2318671-TVWJZVWCGL5KNJR3.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/cHqDMn', 'timeZone': 'America/New_York', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 3, 'items': [{'id': '50379b8de4b0b4924bccca94', 'name': 'Bronx-To-Do List', 'description': '', 'type': 'others', 'user': {'id': '4174003', 'firstName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4174003-TZI2AX1JI53DMMDL.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/4174003/list/bronxtodo-list', 'canonicalUrl': 'https://foursquare.com/user/4174003/list/bronxtodo-list', 'createdAt': 1345821581, 'updatedAt': 1406668591, 'photo': {'id': '4e7bb0fc45dd3b0e49bb387b', 'createdAt': 1316729084, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/05YJ2ENHLKZ4AE ...
#                          ID                  Name  Likes  Rating  Tips
# 0  4c04544df423a593ac83d116  Cumin Indian Cuisine     13     6.0     9
# ( 3 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c281b57e88001b5283bf'}, 'response': {'venue': {'id': '551b7f75498e86c00a0ed2e1', 'name': 'Hungry Bird', 'contact': {'phone': '9178014900', 'formattedPhone': '(917) 801-4900'}, 'location': {'address': '980 Morris Ave', 'crossStreet': '164th and 165th Streets', 'lat': 40.82881986636983, 'lng': -73.91682784225715, 'labeledLatLngs': [{'label': 'display', 'lat': 40.82881986636983, 'lng': -73.91682784225715}], 'postalCode': '10456', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['980 Morris Ave (164th and 165th Streets)', 'Bronx, NY 10456', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/hungry-bird/551b7f75498e86c00a0ed2e1', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'id': '12049990', 'firstName': 'Darryl', 'lastName': 'J', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/DPDECX531OERBHRS.jpg'}}, {'id': '419590198', 'firstName': 'Sharon', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/419590198_uwhNb5cB_IC1qdUiwcG_1MDvpINj6xujtjI77imouQmm0jIwe1Vg9cI-kstuk99DZXx-1xku3.jpg'}}, {'id': '9840630', 'firstName': 'Niji', 'lastName': 'J', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/GIVSFJ2UIOESB2EM.jpg'}}, {'id': '386698941', 'firstName': 'Rite Temp', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/386698941-RB42R4O4L4ZM3M4Q.jpg'}}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 14, 'delivery': {'id': '296817', 'url': 'https://www.seamless.com/menu/hungry-bird-980-morris-ave-bronx/296817?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=296817', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 0, 'groups': []}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1427865461, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '57e145a4498e4f845efba584', 'createdAt': 1474381220, 'text': 'Vegetable samosas are life! Chana masala! All vegetarian options can be made vegan, this place is amazing!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/57e145a4498e4f845efba584', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '156829507', 'firstName': 'blehsyng', 'lastName': '.', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/156829507-I4FAGN2HEDKPQA1H.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1CL0gHo', 'timeZone': 'America/New_York', 'listed': {'count': 5, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 5, 'items': [{'id': '58bb2827730a92457be6e2d4', 'name': 'South Bronx', 'description': '', 'type': 'others', 'user': {'id': '98286', 'firstName': 'Pam', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/98286_1258342398643.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/98286/list/south-bronx', 'canonicalUrl': 'https://foursquare.com/user/98286/list/south-bronx', 'createdAt': 148 ...
#                          ID         Name  Likes  Rating  Tips
# 0  551b7f75498e86c00a0ed2e1  Hungry Bird      8     6.8     3
# ( 4 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c2e9df2774001bda6137'}, 'response': {'venue': {'id': '4c194631838020a13e78e561', 'name': 'Melanies Roti Bar And Grill', 'contact': {'phone': '7184091088', 'formattedPhone': '(718) 409-1088'}, 'location': {'address': '1248 Castle Hill Ave', 'crossStreet': 'Newbold Ave', 'lat': 40.833293, 'lng': -73.85104, 'labeledLatLngs': [{'label': 'display', 'lat': 40.833293, 'lng': -73.85104}, {'label': 'entrance', 'lat': 40.833276, 'lng': -73.851166}], 'postalCode': '10462', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1248 Castle Hill Ave (Newbold Ave)', 'Bronx, NY 10462', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/melanies-roti-bar-and-grill/4c194631838020a13e78e561', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '85063300', 'firstName': 'Herbie', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/85063300-Z0EBLTSF2HA332NN.jpg'}}, {'id': '27574660', 'firstName': 'Ronny', 'lastName': 'O', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/27574660_qYfiOHLf_oBSOCTf25k5xBfNxi46hyVIAru4KIR76_dMR8yoIkJXSlJjtCFwcte3v5ACuyKWL.jpg'}}, {'id': '126099277', 'firstName': 'Michelle', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/126099277-1RYNZ5EKS1WDY5HW.jpg'}}]}], 'summary': '3 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.0, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'delivery': {'id': '72260', 'url': 'https://www.seamless.com/menu/melanies-roti--grill-restaurant-1248-castle-hill-ave-bronx/72260?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72260', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/melanies-roti-bar-and-grill/4c194631838020a13e78e561/menu', 'mobileUrl': 'https://foursquare.com/v/4c194631838020a13e78e561/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1, 'items': [{'id': '4f9ee2d1e4b0e868c4812372', 'createdAt': 1335812817, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/erNpDYL_cghKUK2JjgQFs2bl0MVCEyA9Tzi-UX5cMRo.jpg', 'width': 540, 'height': 720, 'user': {'id': '19512833', 'firstName': 'Tanisha', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KH1ES1XV1UWC1O4S.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1276724785, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '5424b5d1498e2280e91127f3', 'createdAt': 1411691985, 'text': 'Cashier messed up the order I ordered pork lowmein and chicken fried rice. Instead received pork fried rice and chicken fried rice', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5424b5d1498e2280e91127f3', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '27574660', 'firstName': 'Ronny', 'lastName': 'O', 'photo': {'prefix' ...
#                          ID                         Name  Likes  Rating  Tips
# 0  4c194631838020a13e78e561  Melanies Roti Bar And Grill      3     6.0     2
# ( 5 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c09a40a7ea001bf11b1c'}, 'response': {'venue': {'id': '4b5a4dc8f964a520a2bb28e3', 'name': 'Taj Mahal', 'contact': {'phone': '7188361512', 'formattedPhone': '(718) 836-1512'}, 'location': {'address': '7315 3rd Ave', 'lat': 40.632373, 'lng': -74.027193, 'labeledLatLngs': [{'label': 'display', 'lat': 40.632373, 'lng': -74.027193}], 'postalCode': '11209', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['7315 3rd Ave', 'Brooklyn, NY 11209', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/taj-mahal/4b5a4dc8f964a520a2bb28e3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 26}, 'url': 'http://tajmahalbrooklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 38, 'groups': [{'type': 'others', 'count': 38, 'items': []}], 'summary': '38 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 64, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/taj-mahal/4b5a4dc8f964a520a2bb28e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b5a4dc8f964a520a2bb28e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 33, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 33, 'items': [{'id': '4f9c36f5e4b02343c85437be', 'createdAt': 1335637749, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/copRc_ijzbocZTTRIoOJuHcKpefYDjtDb8rICULVJ7c.jpg', 'width': 612, 'height': 612, 'user': {'id': '120077', 'firstName': 'Ron', 'lastName': 'V', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/120077_1259011080955.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1264209352, 'tips': {'count': 26, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 26, 'items': [{'id': '4c156876a5eb76b0ea55c3b7', 'createdAt': 1276471414, 'text': 'If you tell them its your bday you get a nice surprise.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4c156876a5eb76b0ea55c3b7', 'lang': 'en', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': []}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'id': '1544755', 'firstName': 'Rachael', 'lastName': 'Z', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZSYWNPKN2NCIV52O.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/cFoduh', 'timeZone': 'America/New_York', 'listed': {'count': 29, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 29, 'items': [{'id': '4f40f6f6e4b015f1baefe4cc', 'name': 'Like', 'description': '', 'type': 'others', 'user': {'id': '14598049', 'firstName': 'Vanessa', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/GLOW1LX1XIXDL4S1.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/14598049/list/like', 'canonicalUrl': 'https://foursquare.com/user/14598049/list/like', 'createdAt': 1329657590, 'updatedAt': 1469895534, 'photo': {'id': '4e7e413be5fab8674b354aa9', 'createdAt': 1316897083, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/MT0KHJ1WNLAYPJVTBIR4DGDQMMLQ0A45EVVWUX3L5BJSNXWF.jpg', 'width': 431, 'height': 720, 'user': {'id': '5065244', 'firstName': 'Ian', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sq ...
#                          ID       Name  Likes  Rating  Tips
# 0  4b5a4dc8f964a520a2bb28e3  Taj Mahal     38     8.0    26
# ( 6 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c1f8edbcad001bd7bf9c'}, 'response': {'venue': {'id': '545835a1498e820edc6f636f', 'name': 'Bombay Grill', 'contact': {'phone': '7184912500', 'formattedPhone': '(718) 491-2500'}, 'location': {'address': '8716 3rd Ave', 'lat': 40.622371, 'lng': -74.03179899999999, 'labeledLatLngs': [{'label': 'display', 'lat': 40.622371, 'lng': -74.03179899999999}, {'label': 'entrance', 'lat': 40.622344, 'lng': -74.031673}], 'postalCode': '11209', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['8716 3rd Ave', 'Brooklyn, NY 11209', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bombay-grill/545835a1498e820edc6f636f', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 14, 'groups': [{'type': 'others', 'count': 14, 'items': []}], 'summary': '14 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 22, 'delivery': {'id': '300559', 'url': 'https://www.seamless.com/menu/bombay-grill-8716-3rd-ave-brooklyn/300559?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=300559', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 5, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 5, 'items': [{'id': '56fca2e0498e7608f86fa7e1', 'createdAt': 1459397344, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2694817_9Jk8K_KVqA399qTQbAUWfW4kzJxXcVHjXaKeYX9liL8.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '2694817', 'firstName': 'Alexandra', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2694817_BdGa90H2__VtI2aL_zIfjqm0Re3v3cAV4pWsmEr2GlEytg80hMJ1P3tyniz0lieNg83u1BY21.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1415067041, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '586d8d4f9836313406bf6bb2', 'createdAt': 1483574607, 'text': 'Delicious Aloo Tikki', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/586d8d4f9836313406bf6bb2', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '2694817', 'firstName': 'Alexandra', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2694817_BdGa90H2__VtI2aL_zIfjqm0Re3v3cAV4pWsmEr2GlEytg80hMJ1P3tyniz0lieNg83u1BY21.jpg'}}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/1od9qr7', 'timeZone': 'America/New_York', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '57ed532e498edd862aa1b0ae', 'name': 'USA NYC BK South', 'description': 'Industry City, Brooklyn Chinatown, Sunset Park, Bay Ridge, Bensonhurst, Coney Island, Brighton Beach, Sheepshead Bay, Rockaways, & Staten Island.', 'type': 'others', 'user': {'id': '12113441', 'firstName': 'Kino', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/kinosfault/list/usa-nyc-bk-south', 'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-bk-south', 'createdAt': 1 ...
#                          ID          Name  Likes  Rating  Tips
# 0  545835a1498e820edc6f636f  Bombay Grill     14     7.1     4
# ( 7 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c1de6d8c56001ba9ab07'}, 'response': {'venue': {'id': '4af0d31bf964a5207ddf21e3', 'name': 'Pak Nasheman', 'contact': {'phone': '7183328100', 'formattedPhone': '(718) 332-8100'}, 'location': {'address': '3149 Coney Island Ave', 'lat': 40.579254999999996, 'lng': -73.95942600000001, 'labeledLatLngs': [{'label': 'display', 'lat': 40.579254999999996, 'lng': -73.95942600000001}, {'label': 'entrance', 'lat': 40.579252, 'lng': -73.95955}], 'postalCode': '11235', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['3149 Coney Island Ave', 'Brooklyn, NY 11235', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/pak-nasheman/4af0d31bf964a5207ddf21e3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'id': '343666961', 'firstName': 'Daniel', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/343666961_ZcaD5umM_S9c6iNEtrGaCp_PtFfDZj4YvkKfB6OrIh1os3x0ZCk1o6fRm46H6xi3uchT2YUyb.jpg'}}, {'id': '142213323', 'firstName': 'Michael', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '377617081', 'firstName': 'Cengiz', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/377617081_0Mguwr50_fBI5pISt_hV9TZRcqc2XXmkxndySSEqH4K5Xf4CIXl5A_P9w70Pd3vIVk7ebiCOp.jpg'}}, {'id': '455484', 'firstName': 'Deb', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/TAI3QOGLMKDAAHY3.jpg'}}]}], 'summary': '9 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 14, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/pak-nasheman/4af0d31bf964a5207ddf21e3/menu', 'mobileUrl': 'https://foursquare.com/v/4af0d31bf964a5207ddf21e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 10, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 10, 'items': [{'id': '53ceabc8498e48a195ca8f65', 'createdAt': 1406053320, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1597391_T9M3OAMAmXDzxLLFhECxv_shhWs5hD7QMbAooXmZcbM.jpg', 'width': 960, 'height': 720, 'user': {'id': '1597391', 'firstName': 'Eva', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/APAFHFW5ZIRBV5BH.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257296667, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5a00feda6661165f57959080', 'createdAt': 1510014682, 'text': 'All the food is fantastic, the staff is nice, and the prices are great.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5a00feda6661165f57959080', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '455484', 'firstName': 'Deb', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/TAI3QOGLMKDAAHY3.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/cZ0P5Z', 'timeZone': 'America/New_York', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 3, 'items': [{'id': '59beac95febf31658c17a81b ...
#                          ID          Name  Likes  Rating  Tips
# 0  4af0d31bf964a5207ddf21e3  Pak Nasheman      9     7.5     4
# ( 8 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c1d8ad1ab4001c358fd4'}, 'response': {'venue': {'id': '52213c4211d295d4c57a607c', 'name': 'Ashoka Grill', 'contact': {'phone': '7184341001', 'formattedPhone': '(718) 434-1001'}, 'location': {'address': '1436 Flatbush Ave', 'crossStreet': 'Farragut Avenue', 'lat': 40.635821694890055, 'lng': -73.95081967691863, 'labeledLatLngs': [{'label': 'display', 'lat': 40.635821694890055, 'lng': -73.95081967691863}, {'label': 'entrance', 'lat': 40.635644, 'lng': -73.950869}], 'postalCode': '11210', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1436 Flatbush Ave (Farragut Avenue)', 'Brooklyn, NY 11210', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/ashoka-grill/52213c4211d295d4c57a607c', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 14}, 'url': 'http://ashokagrill.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'id': '4944800', 'firstName': 'Rani', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/IYBRLTSKPE2U0QTV.jpg'}}, {'id': '23846778', 'firstName': 'Anitra', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/23846778_B63waaF5_MWt5HROABFXpFRCl5wTqyh2ifnxH14S3mxE3FfnCteWQZmRz1GenvLOkxka2dpMz.jpg'}}, {'id': '3287341', 'firstName': 'Tara', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/3287341-30GU11XLDAG3EJWI.jpg'}}, {'id': '142714', 'firstName': 'Steve', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/5ZSHMBJ3US5OTLNB.jpg'}}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 21, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 16, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 16, 'items': [{'id': '5924f5dc840fc26f705540a8', 'createdAt': 1495594460, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/23846778_z6SEKmyqvKLv0JT6zm2xBtqOnKHOn_YMfmMdzcc-Yqk.jpg', 'width': 4096, 'height': 2304, 'user': {'id': '23846778', 'firstName': 'Anitra', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/23846778_B63waaF5_MWt5HROABFXpFRCl5wTqyh2ifnxH14S3mxE3FfnCteWQZmRz1GenvLOkxka2dpMz.jpg'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '80569424'}, 'reasons': {'count': 0, 'items': []}, 'page': {'user': {'id': '80569424', 'firstName': 'Ashoka Grill', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/80569424-XFICUEQL4EXTIGZA.png'}, 'type': 'venuePage', 'venue': {'id': '52213c4211d295d4c57a607c'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1377909826, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '52759a1511d255772d8d07d1', 'createdAt': 1383438869, 'text': "True, great Indian food. This is what we're looking for as New Yorkers.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52759a1511d255772d8d07d1', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '95409467', 'firstName': 'brooklyn', 'lastName': 'f', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '63389256', 'firstName': 'Angela', 'lastName' ...
#                          ID          Name  Likes  Rating  Tips
# 0  52213c4211d295d4c57a607c  Ashoka Grill      8     7.1    14
# ( 9 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c218542890001b6bcb4d'}, 'response': {'venue': {'id': '564d283d498e6e851df79d87', 'name': 'Great Indian Curry', 'contact': {'phone': '3475901133', 'formattedPhone': '(347) 590-1133'}, 'location': {'address': '1241 Flatbush Ave', 'crossStreet': 'Newkirk & Ave D', 'lat': 40.63979849275365, 'lng': -73.95251572219995, 'labeledLatLngs': [{'label': 'display', 'lat': 40.63979849275365, 'lng': -73.95251572219995}], 'postalCode': '11226', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1241 Flatbush Ave (Newkirk & Ave D)', 'Brooklyn, NY 11226', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/great-indian-curry/564d283d498e6e851df79d87', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'url': 'http://www.greatindiancurry33.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '834491', 'firstName': 'Jason', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/834491-AGL3WTZIMHPMYMHV.jpg'}}, {'id': '2242016', 'firstName': 'Graylyn', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2242016_O-T1srt1_Kgd_Pr7yS9lYR3MssrGVytSOs8wjnqhrqLkDilb0mX4LBVjiFfK3DzEO3kDzJa8j.jpg'}}, {'id': '47321', 'firstName': 'Nate', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/47321_7-SPk1Ml_yiKec52usgfszPx8O30OFhIe9epxw83ZYW8qbNkwYSlM0EHJnyMqZRWE1ejuhsXj'}}]}], 'summary': '3 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.9, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1, 'items': [{'id': '565768f5498e39700a9961ef', 'createdAt': 1448569077, 'source': {'name': '4sq for iOS (internal)', 'url': 'http://developer.foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/47321_qseuDGAYjcmwgmnFSBowIZU8aIxShcyN9T6XOLb5P5Y.jpg', 'width': 1920, 'height': 1440, 'user': {'id': '47321', 'firstName': 'Nate', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/47321_7-SPk1Ml_yiKec52usgfszPx8O30OFhIe9epxw83ZYW8qbNkwYSlM0EHJnyMqZRWE1ejuhsXj'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1447897149, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '565768f338fa57a4694bbc5e', 'createdAt': 1448569075, 'text': 'perfectly spicy and creamy chicken tikka masala', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/565768f338fa57a4694bbc5e', 'photo': {'id': '565768f5498e39700a9961ef', 'createdAt': 1448569077, 'source': {'name': '4sq for iOS (internal)', 'url': 'http://developer.foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/47321_qseuDGAYjcmwgmnFSBowIZU8aIxShcyN9T6XOLb5P5Y.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/47321_qseuDGAYjcmwgmnFSBowIZU8aIxShcyN9T6XOLb5P5Y.jpg', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '47321', 'firstName': 'Nate', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/47321_7-SPk1Ml_yiKec52usgfszPx8O30OFhIe9epxw83ZYW8qbNkwYSlM0EHJnyMqZRWE1ejuhsXj'}}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '47321' ...
#                          ID                Name  Likes  Rating  Tips
# 0  564d283d498e6e851df79d87  Great Indian Curry      3     6.9     2
# ( 10 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c217c8cff2001ca95cc3'}, 'response': {'venue': {'id': '512a9ea9e4b004fb8eeb84e5', 'name': 'Silver Krust', 'contact': {'phone': '7186290010', 'formattedPhone': '(718) 629-0010'}, 'location': {'address': '5253 Avenue D', 'crossStreet': 'E.53rd st', 'lat': 40.64249, 'lng': -73.926862, 'labeledLatLngs': [{'label': 'display', 'lat': 40.64249, 'lng': -73.926862}, {'label': 'entrance', 'lat': 40.64241, 'lng': -73.926689}], 'postalCode': '11203', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['5253 Avenue D (E.53rd st)', 'Brooklyn, NY 11203', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/silver-krust/512a9ea9e4b004fb8eeb84e5', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 12, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 2, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 2, 'items': [{'id': '53ed2658498ef1a179f2e1e7', 'createdAt': 1408050776, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/868614_KTD-rT6l7XchFChSzPLDFLLZ_R02l9mfJyGOHX2GfW4.jpg', 'width': 720, 'height': 960, 'user': {'id': '868614', 'firstName': 'Summer', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/868614-VDHT3WCXK3EX2ROX.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1361747625, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5720a380498e0a5aea2d9e54', 'createdAt': 1461756800, 'text': "I have been there On a number of occasions and they have an employee environment of impolite service. It's a shame because they sell great food.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5720a380498e0a5aea2d9e54', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '104642678', 'firstName': 'Kevin', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/104642678-4VDJOBY0J5HP2SH4.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/YrJE2B', 'timeZone': 'America/New_York', 'listed': {'count': 2, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 2, 'items': [{'id': '5a27b5b58d0a534a10c5bc65', 'name': 'New York city/Brooklyn', 'description': 'Caribbean cuisine', 'type': 'others', 'user': {'id': '134875782', 'firstName': 'Carolyn', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_girl.png', 'default': True}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/134875782/list/new-york-citybrooklyn', 'canonicalUrl': 'https://foursquare.com/user/134875782/list/new-york-citybrooklyn', 'createdAt': 1512551861, 'updatedAt': 1512551892, 'followers': {'count': 0}, 'listItems': {'count': 2, 'items': [{'id': 'v512a9ea9e4b004fb8eeb84e5', 'createdAt': 1512551892}]}}, {'id': '5ade579c535d6f2ab64f653b', 'name': 'Indian Restaurants', 'description': '', 'type': 'others', 'user': {'id': '493434985', 'firstName': 'Diana', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/493434985_AGrEl5YS_4z2UGHJIHZ5aLDyTwhnFn5mOFjb5_jJc ...
#                          ID          Name  Likes  Rating  Tips
# 0  512a9ea9e4b004fb8eeb84e5  Silver Krust     13     8.3     3
# ( 11 / 140 ) processed
# ...
#                          ID   Name  Likes  Rating  Tips
# 0  57f7cbbe498edf8f07c7ba83  Sahib     60     8.6    13
# ( 47 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c2056d8c56001ba9f561'}, 'response': {'venue': {'id': '4a12eb1ff964a52099771fe3', 'name': 'Dhaba', 'contact': {'phone': '2126791284', 'formattedPhone': '(212) 679-1284', 'twitter': 'dhabanyc', 'facebook': '603662103041500', 'facebookUsername': 'dhabanyc', 'facebookName': 'Dhaba Indian Cuisine'}, 'location': {'address': '108 Lexington Ave', 'crossStreet': 'btwn 27th & 28th St.', 'lat': 40.74233843496071, 'lng': -73.98274966362429, 'labeledLatLngs': [{'label': 'display', 'lat': 40.74233843496071, 'lng': -73.98274966362429}, {'label': 'entrance', 'lat': 40.74236, 'lng': -73.982826}], 'postalCode': '10016', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['108 Lexington Ave (btwn 27th & 28th St.)', 'New York, NY 10016', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/dhaba/4a12eb1ff964a52099771fe3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 164}, 'url': 'http://www.dhabanyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 497, 'groups': [{'type': 'others', 'count': 497, 'items': []}], 'summary': '497 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 714, 'delivery': {'id': '300512', 'url': 'https://www.seamless.com/menu/dhaba-108-lexington-ave-new-york/300512?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=300512', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/dhaba/4a12eb1ff964a52099771fe3/menu', 'mobileUrl': 'https://foursquare.com/v/4a12eb1ff964a52099771fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 281, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 281, 'items': [{'id': '515c7327e4b0b5f270e38f26', 'createdAt': 1365013287, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4460285_NhlCgTB7qguWWN5nJf_-7bqROx4p1b0y-kPjC1OF8wU.jpg', 'width': 960, 'height': 720, 'user': {'id': '4460285', 'firstName': 'Craig', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/IVQWKHGHKZEV1YBU.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Consistently rated as a top Indian Restaurant in NYC, Dhaba offers diners authentic and tasty cuisine from the Punjab Region in India.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1242753823, 'tips': {'count': 164, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 164, 'items': [{'id': '4e8c9d5f02d5fc3ab2eef2b3', 'createdAt': 1317838175, 'text': 'Try the crunchy purani delhi ki papri chaat, composed of a layer of fried wheat discs piled with chickpeas and diced potatoes. It’s one of our #100best dishes and drinks of 2011.', 'type': 'user', 'url': 'http://tmout.us/ndAT6p', 'canonicalUrl': 'https://foursquare.com/item/4e8c9d5f02d5fc3ab2eef2b3', 'lang': 'en', 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 likes'}, 'logView': True, 'agreeCount': 12, 'disagreeCount': 0, 'todo': {'count': 59}, 'user': {'id': '742542', 'firstName': 'Time Out New York', 'photo': {'prefix': 'htt ...
#                          ID   Name  Likes  Rating  Tips
# 0  4a12eb1ff964a52099771fe3  Dhaba    497     8.3   164
# ( 48 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c16ca2e538001b8e04bd'}, 'response': {'venue': {'id': '4fcf82f54fc6ada5874da997', 'name': 'Chote Nawab', 'contact': {'phone': '2126794603', 'formattedPhone': '(212) 679-4603', 'twitter': 'chotenawab2', 'facebook': '600950589992112', 'facebookUsername': 'ChoteNawabNYC', 'facebookName': 'Chote Nawab Fine Indian Cuisine'}, 'location': {'address': '115 Lexington Ave', 'lat': 40.74258451651163, 'lng': -73.98239607093032, 'labeledLatLngs': [{'label': 'display', 'lat': 40.74258451651163, 'lng': -73.98239607093032}], 'postalCode': '10016', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['115 Lexington Ave', 'New York, NY 10016', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/chote-nawab/4fcf82f54fc6ada5874da997', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 70}, 'url': 'http://www.chotenawabnyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 215, 'groups': [{'type': 'others', 'count': 215, 'items': []}], 'summary': '215 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 321, 'delivery': {'id': '300506', 'url': 'https://www.seamless.com/menu/chote-nawab-115-lexington-ave-new-york/300506?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=300506', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/chote-nawab/4fcf82f54fc6ada5874da997/menu', 'mobileUrl': 'https://foursquare.com/v/4fcf82f54fc6ada5874da997/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 100, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 100, 'items': [{'id': '510c5fa6e4b03a116d332981', 'createdAt': 1359765414, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/110240_9e3PErvC6wFU9leoWW5qvun4WE57kuNl2tKJRIVl18o.jpg', 'width': 960, 'height': 720, 'user': {'id': '110240', 'firstName': 'Pradeep', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/110240-WUNUCQZ2OHEXPY1R.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Casual dining. Enjoy our famous kebabs and dum biryani rice pots.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1338999541, 'tips': {'count': 70, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 70, 'items': [{'id': '523b1434498e2eb493aac742', 'createdAt': 1379603508, 'text': 'An expansive menu with plenty of uncommon Indian regional specialties. Go for binda sasuralwali, "Okra you would eat at your in laws\' house."', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/523b1434498e2eb493aac742', 'lang': 'en', 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'id': '26910457', 'firstName': 'Tiffany', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/26910457-DQ0Y40NKNNGI5AVY.jpg'}}, {'id': '66597847', 'firstName': 'Linda', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/PRJHO3NGGI3QTHLR.jpg'}}, {'id': '38053539', 'firstName': 'Kappie', 'lastName': 'F', 'photo': {'prefix': 'http ...
#                          ID         Name  Likes  Rating  Tips
# 0  4fcf82f54fc6ada5874da997  Chote Nawab    215     8.3    70
# ( 49 / 140 ) processed
# {'meta': {'code': 200, 'requestId': '5eb3c23dc8cff2001ca9a45d'}, 'response': {'venue': {'id': '43d537d0f964a520402e1fe3', 'name': 'Vatan', 'contact': {'phone': '2126895666', 'formattedPhone': '(212) 689-5666'}, 'location': {'address': '409 3rd Ave', 'crossStreet': 'at 29th', 'lat': 40.74244047116085, 'lng': -73.98046073418793, 'labeledLatLngs': [{'label': 'display', 'lat': 40.74244047116085, 'lng': -73.98046073418793}, {'label': 'entrance', 'lat': 40.742363, 'lng': -73.980374}], 'postalCode': '10016', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['409 3rd Ave (at 29th)', 'New York, NY 10016', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/vatan/43d537d0f964a520402e1fe3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 46}, 'url': 'http://vatanny.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 132, 'groups': [{'type': 'others', 'count': 132, 'items': []}], 'summary': '132 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 187, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/vatan/43d537d0f964a520402e1fe3/menu', 'mobileUrl': 'https://foursquare.com/v/43d537d0f964a520402e1fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 131, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 131, 'items': [{'id': '51c3c177498e5d4ddedb74e9', 'createdAt': 1371783543, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/26102786_7dFHB8rHGf8uwpePXULF_Ymec7xN1tNhk8NTlEusxh0.jpg', 'width': 960, 'height': 720, 'user': {'id': '26102786', 'firstName': 'Rhea', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZNXIISHDYOHBMTIG.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1138046928, 'tips': {'count': 46, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 46, 'items': [{'id': '4d7d940f8700370402546199', 'createdAt': 1300075535, 'text': "Its a pre fix menu n its alot of food for 29.95. No meat but u won't even miss it. Must try it", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4d7d940f8700370402546199', 'lang': 'en', 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'id': '28183617', 'firstName': 'Chaitenya', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/VKNE1IC2ZVTMUTW4.jpg'}}, {'id': '66552', 'firstName': 'Jermyn', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/66552-BXIMIAZMVLUCAGH3'}}]}], 'summary': '5 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 4}, 'user': {'id': '4482962', 'firstName': 'Christina', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/UYLYGNREK4WBJO1A.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/69vtrI', 'timeZone': 'America/New_York', 'listed': {'count': 273, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 273, 'items': [{'id': '51d82a8b498e1aad957ce8cd', 'name': 'NYC Vegan', 'description': '', 'type': 'others', 'user': {'id': '32355263', 'firstName': 'Alex', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/32355263-20EQZOCGWDEBRRUK.jpg'}}, ' ...
#                          ID   Name  Likes  Rating  Tips
# 0  43d537d0f964a520402e1fe3  Vatan    132     8.1    46
# ( 50 / 140 ) processed
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eb3c1cfb9a389001b04276b'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-10411ff430c3> in <module>
#       8     Borough,Neighborhood,ID,Name=row
#       9     try:
# ---> 10         venue_details=get_venue_details(ID)
#      11         print(venue_details)
#      12         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-80-4054bfa18d05> in get_venue_details(venue_id)
#      15     results = requests.get(url).json()
#      16     print(results)
# ---> 17     venue_data=results['response']['venue']
#      18     venue_details=[]
#      19     try:
#
# KeyError: 'venue'

# %% [markdown]
# Above function was called with intervals because 50 calls limit is there. Now that we got data for all resturants. As the number of calls to get details for venue are premium call and have limit of 500 per day, we will refer to saved data sheet csv if required.

# %%
#indian_rest_stats_ny.to_csv('indian_rest_stats_ny_50.csv', index=False)
#indian_rest_stats_ny

# %% [markdown]
# Lets verify the data from saved csv file.

# %%
indian_rest_stats_ny=pd.read_csv('indian_rest_stats_ny.csv')

# %%
indian_rest_stats_ny.shape
# Out:
# (151, 7)

# %%
indian_rest_stats_ny.head()
# Out:
#   Borough    Neighborhood                        ID  \
# 0   Bronx        Woodlawn  4c0448d9310fc9b6bf1dc761
# 1   Bronx     Parkchester  4c194631838020a13e78e561
# 2   Bronx  Spuyten Duyvil  4c04544df423a593ac83d116
# 3   Bronx       Concourse  551b7f75498e86c00a0ed2e1
# 4   Bronx       Unionport  4c194631838020a13e78e561
#
#                           Name  Likes  Rating  Tips
# 0                   Curry Spot      5     7.6    10
# 1  Melanies Roti Bar And Grill      3     5.8     2
# 2         Cumin Indian Cuisine     13     6.1     9
# 3                  Hungry Bird      8     6.9     3
# 4  Melanies Roti Bar And Grill      3     5.8     2

# %%
indian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       151 non-null    object
#  1   Neighborhood  151 non-null    object
#  2   ID            151 non-null    object
#  3   Name          151 non-null    object
#  4   Likes         151 non-null    int64
#  5   Rating        151 non-null    float64
#  6   Tips          151 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.4+ KB

# %% [markdown]
# The Data type of 'Likes' and  'Tips' are of type 'String'. we will convert them into type 'Float' for further analysis.

# %%
indian_rest_stats_ny['Likes']=indian_rest_stats_ny['Likes'].astype('float64')
indian_rest_stats_ny['Tips']=indian_rest_stats_ny['Tips'].astype('float64')

# %%
indian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       151 non-null    object
#  1   Neighborhood  151 non-null    object
#  2   ID            151 non-null    object
#  3   Name          151 non-null    object
#  4   Likes         151 non-null    float64
#  5   Rating        151 non-null    float64
#  6   Tips          151 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 8.4+ KB

# %% [markdown]
# Now we will find the Indian restuarants with Maximum Likes, Maximum Ratings and Maximum Tips.

# %%
# Resturant with maximum Likes
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Midtown
# ID              49d91c12f964a520015e1fe3
# Name               The Kati Roll Company
# Likes                                837
# Rating                               8.8
# Tips                                 260
# Name: 37, dtype: object

# %%
# Resturant with maximum Rating
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Tribeca
# ID              4bbb9dbded7776b0e1ad3e51
# Name                    Tamarind TriBeCa
# Likes                                589
# Rating                               9.1
# Tips                                 146
# Name: 40, dtype: object

# %%
# Resturant with maximum Tips
indian_rest_stats_ny.iloc[indian_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Midtown
# ID              49d91c12f964a520015e1fe3
# Name               The Kati Roll Company
# Likes                                837
# Rating                               8.8
# Tips                                 260
# Name: 37, dtype: object

# %% [markdown]
# Next lets visualize neighborhood with maximum average rating of resturants.

# %%
ny_neighborhood_stats=indian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#      Neighborhood  Average Rating
# 12   Civic Center        9.100000
# 69        Tribeca        9.100000
# 0         Astoria        9.000000
# 5      Blissville        9.000000
# 75   West Village        8.800000
# 44  Midtown South        8.800000
# 43        Midtown        8.800000
# 29       Gramercy        8.733333
# 25    Fort Greene        8.700000
# 11        Chelsea        8.700000

# %% [markdown]
# ### Above are the top neighborhoods with top average rating of Indian resturants.

# %% [markdown]
# Similarly we will find the average rating of Indian Resturants for each Borough.

# %%
ny_borough_stats=indian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#          Borough  Average Rating
# 2      Manhattan        8.210000
# 1       Brooklyn        7.700000
# 3         Queens        6.552113
# 0          Bronx        5.585714
# 4  Staten Island        3.533333

# %% [markdown]
# Lets Visualize it.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of Indian Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
#giving a bar plot
indian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# We will consider all the neighborhoods with average rating greater or equal 9.0 to visualize on map.

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=9.0]

# %%
ny_neighborhood_stats
# Out:
#     Neighborhood  Average Rating
# 0        Astoria             9.0
# 5     Blissville             9.0
# 12  Civic Center             9.1
# 69       Tribeca             9.1

# %% [markdown]
# We will join this dataset to original new york data to get lonitude and latitude.

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')

# %%
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]

# %%
ny_neighborhood_stats
# Out:
#      Borough  Neighborhood   Latitude  Longitude  Average Rating
# 0     Queens       Astoria  40.768509 -73.915654             9.0
# 1     Queens    Blissville  40.737251 -73.932442             9.0
# 2  Manhattan  Civic Center  40.715229 -74.005415             9.1
# 3  Manhattan       Tribeca  40.721522 -74.010683             9.1

# %% [markdown]
# Finally, Let's show this data on a map.

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the neighborhood and add each to the feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %% [markdown]
# Lets add a new field to dataframe for labeling purpose.

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have visualized the Neighborhoods.
# Lets Visualize Boroughs based on average Rating.

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = r'Borough_Boundaries.geojson'

map = ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)

# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_ratings.html')

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### So now we can answer the questions asked above in the Questions section of the notebook.
# ### From our anaysis the answers to the above questions are:

# %% [markdown]
# #### A1) Astoria(Queens), Blissville(Queens), Civic Center(Manhattan) are some of the best neighborhoods for Indian cuisine.
# #### A2) Manhattan have potential Indian Resturant Market.
# #### A3) Staten Island ranks last in average rating of Indian Resturants.
# #### A4) Manhattan is the best place to stay if you prefer Indian Cuisine.
